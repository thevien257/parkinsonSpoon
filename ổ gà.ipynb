# %% [markdown]
# <a href="https://colab.research.google.com/github/thevien257/parkinsonSpoon/blob/master/%E1%BB%95%20g%C3%A0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 910.2/910.2 kB 40.2 MB/s eta 0:00:00
# ...

# %%
pip install -U albumentations
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.0/66.0 kB 3.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 273.9/273.9 kB 16.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 632.7/632.7 kB 9.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: albucore
#     Found existing installation: albucore 0.0.19
#     Uninstalling albucore-0.0.19:
#       Successfully uninstalled albucore-0.0.19
#   Attempting uninstall: albumentations
#     Found existing installation: albumentations 1.4.20
#     Uninstalling albumentations-1.4.20:
#       Successfully uninstalled albumentations-1.4.20
# ...

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="9nSFUtk0dVuAxX6t0DjQ")
project = rf.workspace("demo-tracking").project("sub-potholes")
version = project.version(2)
dataset = version.download("yolov11")
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.5/81.5 kB 7.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.8/66.8 kB 5.9 MB/s eta 0:00:00
# ...
#   Attempting uninstall: idna
#     Found existing installation: idna 3.10
#     Uninstalling idna-3.10:
#       Successfully uninstalled idna-3.10
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to sub-potholes-2 in yolov11:: 100%|██████████| 2659/2659 [00:00<00:00, 4613.72it/s]

# %%
import torch
torch.cuda.empty_cache()

# %%
! yolo detect train data=/content/sub-potholes-2/data.yaml model=yolo11s.pt epochs=200 imgsz = 640 batch=32
# Out:
# Ultralytics 8.3.63 🚀 Python-3.10.12 torch-2.5.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %%
from ultralytics import YOLO
model = YOLO ("/content/runs/detect/train/weights/best.pt")
results = model ("/content/sub-potholes-2/train/images/img-621_jpg.rf.b9566c27707647794b6368ec61e663f2.jpg", save = True)
# Out:
# image 1/1 /content/sub-potholes-2/train/images/img-621_jpg.rf.b9566c27707647794b6368ec61e663f2.jpg: 640x640 11 potholes, 19.3ms
# Speed: 1.8ms preprocess, 19.3ms inference, 1.8ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs/detect/predict3
